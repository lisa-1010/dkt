# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from utils import *
from sklearn.model_selection import train_test_split
# %matplotlib notebook

# %%
minlen = 3

# %%
x, y, student_ids = load_data_will_student_solve_next_problem(hoc_num=18, minlen=minlen, return_student_ids=True)
x_train, x_test, y_train, y_test, student_ids_train, student_ids_test = train_test_split(x, y, student_ids, test_size=0.1, random_state=42)
# Out:
# Loading data...
# Data loaded.

# %%
y_test = np.argmax(y_test, axis=1)

# %%
tsne_result = np.load(open('tsne_results_3d.npy', 'rb+'))

# %%
dim_0 = np.reshape(tsne_result[:,0], tsne_result.shape[0])
dim_1 = np.reshape(tsne_result[:,1], tsne_result.shape[0])
dim_2 = np.reshape(tsne_result[:,2], tsne_result.shape[0])

# %%
sampled_indices = np.random.choice(np.array(range(len(dim_0))), size=1000)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(dim_0[sampled_indices], dim_1[sampled_indices], dim_2[sampled_indices], c=y_test[sampled_indices], marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
tsne_result_2d = np.load(open('tsne_results_2d.npy', 'rb+'))

# %%
from matplotlib import style
style.use('ggplot')
fig = plt.figure()
dim_0 = np.reshape(tsne_result_2d[:,0], tsne_result_2d.shape[0])
dim_1 = np.reshape(tsne_result_2d[:,1], tsne_result_2d.shape[0])
plt.scatter(dim_0, dim_1, c=y_test)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
